# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import seaborn as sns
import pingouin as pg
from nilearn import plotting
from matplotlib.colors import LogNorm
import mne

from src import data

# %matplotlib widget

# !date -I
# Out:
# 2024-04-11

# %%
plt.rcParams['figure.figsize'] = [15, 5]

# %% [markdown]
# ## Structural connectivity - Glasser parcellation
#
# - SC Rosen-Halgren s Glasser parcelací vychází nejlépe, pojďme zjistit, jak to
# - Glasser: <https://neuroimaging-core-docs.readthedocs.io/en/latest/pages/atlases.html#id4>
# - Ros-Hal: <https://zenodo.org/records/10150880>???, data, se kterými jsem pracovala původně: <https://zenodo.org/records/6097026>

# %% [markdown]
# ### Load structural (and functional) connectivity data

# %%
SC_W_RH1, _ = data.load_rosen_halgren()
SC_W_RH2, SC_L_RH2 = data.load_rosen_halgren()
labels = np.loadtxt(data.path('external/OLD_rosen_halgren/public_PLoSBio_final/roi.txt'), dtype=str)

# tohle nakonec vůbec není třeba
centroids_file = pd.read_csv(data.path('external/glasser_parcellation_centriods/HCP-MMP1_UniqueRegionList.csv'))

def premute_region_name(name):
    if name[:3] == "7Pl":
        name = "7PL"+ name[3:]
    if name[-1] == 'L':
        return 'L_' + name[:-2]
    else:
        return 'R_' + name[:-2]

centroids_file["regionName_permuted"] = centroids_file["regionName"].apply(premute_region_name)
centroids_file
for i,j in zip(centroids_file["regionName_permuted"],labels):
    if i !=j:
        print(i,j)
# ok, labels for centroids and SC matrix are the same

ED = data.glasser_roi_distances()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/fi_muni/0_diplomka/__venv__/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 23
#      20         print(i,j)
#      21 # ok, labels for centroids and SC matrix are the same
# ---> 23 ED = data.glasser_roi_distances()
#
# File ~/fi_muni/0_diplomka/src/data.py:214, in glasser_roi_distances(reference_labels)
#     211 centroids[:,2] = centroids_file["z-cog"]
#     213 distance_matrix = roi_distances_from_centroids(centroids)
# --> 214 return roi_remappnig.reorder_matrix_based_on_reference(labels,reference_labels,distance_matrix)
#
# File ~/fi_muni/0_diplomka/src/roi_remappnig.py:5, in reorder_matrix_based_on_reference(labels, reference_labels, matrix)
#       3 def reorder_matrix_based_on_reference(labels, reference_labels, matrix):
#       4     df_matrix = pd.DataFrame(matrix, index=labels, columns=labels)
# ----> 5     df_matrix = df_matrix.loc[reference_labels,reference_labels]
#       7     return df_matrix.to_numpy()
#
# File ~/fi_muni/0_diplomka/__venv__/lib/python3.10/site-packages/pandas/core/indexing.py:1146, in _LocationIndexer.__getitem__(self, key)
#    1144     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145     if self._is_scalar_access(key):
# -> 1146         return self.obj._get_value(*key, takeable=self._takeable)
#    1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#
# File ~/fi_muni/0_diplomka/__venv__/lib/python3.10/site-packages/pandas/core/frame.py:4008, in DataFrame._get_value(self, index, col, takeable)
#    4005     series = self._ixs(col, axis=1)
#    4006     return series._values[index]
# -> 4008 series = self._get_item_cache(col)
#    4009 engine = self.index._engine
#    4011 if not isinstance(self.index, MultiIndex):
#    4012     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4013     #  results if our categories are integers that dont match our codes
#    4014     # IntervalIndex: IntervalTree has no get_loc
#
# File ~/fi_muni/0_diplomka/__venv__/lib/python3.10/site-packages/pandas/core/frame.py:4417, in DataFrame._get_item_cache(self, item)
#    4412 res = cache.get(item)
#    4413 if res is None:
#    4414     # All places that call _get_item_cache have unique columns,
#    4415     #  pending resolution of GH#33047
# -> 4417     loc = self.columns.get_loc(item)
#    4418     res = self._ixs(loc, axis=1)
#    4420     cache[item] = res
#
# File ~/fi_muni/0_diplomka/__venv__/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: None

# %%
def plot_adjacency_matrix(matrix,ax,title,norm=None,mask=None):

    g =sns.heatmap(matrix,ax=ax,square=True,cbar=False,yticklabels=False, xticklabels=False,cmap='gray',norm=norm,mask=mask)
    g.set_facecolor('k')
    ax.set_title(title)

# %% [markdown]
# # Structural connectivity - weights

# %%
fig, axs = plt.subplots(1, 2, tight_layout=True,figsize=(10,6),sharey=True,sharex=True)
fig.suptitle("Structural connectivity")
plot_adjacency_matrix(SC_W_RH1,axs[0],"RosHal 1 W (log)",norm=LogNorm(),mask=SC_W_RH1==0)
plot_adjacency_matrix(SC_W_RH2,axs[1],"RosHal 2 W (log)",mask=SC_W_RH2==0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pg.corr(SC_W_RH1.flatten(),SC_W_RH2.flatten(),method='spearman')
# Out:
#                n         r         CI95%  p-val  power
# spearman  129240  0.985955  [0.99, 0.99]    0.0    1.0

# %%
df = pd.DataFrame({'1':np.log10(SC_W_RH1).flatten(),'2':SC_W_RH2.flatten()})
# Out:
# /tmp/ipykernel_43801/1144876629.py:1: RuntimeWarning: divide by zero encountered in log10
#   df = pd.DataFrame({'1':np.log10(SC_W_RH1).flatten(),'2':SC_W_RH2.flatten()})

# %%
pg.pairwise_corr(df)
# Out:
#    X  Y   method alternative       n         r         CI95%  p-unc BF10  \
# 0  1  2  pearson   two-sided  129240  0.987658  [0.99, 0.99]    0.0  nan
#
#    power
# 0    1.0

# %%
plt.figure()
sns.histplot(df,multiple='dodge',bins = 30)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def get_lengths(matrix,ED):
    np.fill_diagonal(ED,np.nan)
    mask = matrix > 0
    return np.where(mask,ED,np.nan).flatten()

df_len = pd.DataFrame({"1":get_lengths(SC_W_RH1,ED),"2":get_lengths(SC_W_RH2,ED)})

# %%
plt.figure(figsize=(10,5))
sns.ecdfplot(df_len)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Create SC matrix from MICA-MICS

# %%
counts_file = data.path(f"external/mica-mics/schaefer200/sub-HC{i+1:03d}_ses-01_space-dwinative_atlas-schaefer200_desc-sc.txt")

# %%
index = list(range(15,15)) + list(range(116,376))
with open(counts_file,"r") as cf:
    c = np.genfromtxt(cf,delimiter=',')
    c = c + c.T
plt.matshow(np.log(c))
# Out:
# /tmp/ipykernel_19325/4091790761.py:4: RuntimeWarning: divide by zero encountered in log
#   plt.matshow(np.log(c))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import os

path_to_dir = data.path('external/mica-mics/schaefer200')
number_of_subjects = 50

M = np.zeros((50,360,360))

index = list(range(15,195)) + list(range(196,376))

for i in range(number_of_subjects):
    counts_file = path_to_dir+f"/sub-HC{i+1:03d}_ses-01_space-dwinative_atlas-schaefer200_desc-sc.txt"
    with open(counts_file,"r") as cf:
        c = np.genfromtxt(cf,delimiter=',')
        c = np.take(c,indices=index,axis=0)
        c = np.take(c,indices=index,axis=1)
        M[i] = c + c.T

# %%
plt.figure()
plt.imshow(np.log(M[42]))
plt.show()
# Out:
# /tmp/ipykernel_43801/3172574745.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(M[42]))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
M_mean = np.mean(M,axis=0)
SC = np.zeros(M_mean.shape)

for i in range(360):
    for j in range(360):
        SC[i][j] = M_mean[i][j] / (np.sum(M_mean[i,:]) + np.sum(M_mean[:,j]) - M_mean[i][i] - M_mean[j][j])

np.fill_diagonal(SC,np.nan)

print(pg.corr(SC.flatten(),SC_W_RH2.flatten(),method='spearman'))

# vypadá to, že je to ok, ale kdyby bylo něco k těm indexům někde napsáno, tak bych se nezlobila
# Out:
#                n         r         CI95%  p-val  power
# spearman  129240  0.825646  [0.82, 0.83]    0.0    1.0

# %%
plt.figure()
plt.imshow(np.log(SC))
plt.show()
# Out:
# /tmp/ipykernel_43801/1123566848.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(SC))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.save("test.npy",np.log10(SC))
# Out:
# /tmp/ipykernel_43801/4021108226.py:1: RuntimeWarning: divide by zero encountered in log10
#   np.save("test.npy",np.log10(SC))
